# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# Data Collection
data = pd.read_csv(r"D:\Datasets for ML\sonar data.csv")
data.head(5)
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
data.shape
# Out:
# (207, 61)

# %%
data.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111  ...      0.0232  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
data['R'].value_counts()
# Out:
# R
# M    111
# R     96
# Name: count, dtype: int64

# %%
data.groupby('R').mean()
# Out:
#      0.0200    0.0371    0.0428    0.0207    0.0954    0.0986    0.1539  \
# R
# M  0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R  0.022524  0.030232  0.035879  0.041664  0.061680  0.096199  0.113767
#
#      0.1601    0.3109    0.2111  ...    0.0232    0.0027    0.0065    0.0159  \
# R                                ...
# M  0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R  0.117153  0.135584  0.158785  ...  0.012198  0.010533  0.009673  0.009451
#
#      0.0072    0.0167    0.0180    0.0084    0.0090    0.0032
# R
# M  0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R  0.008581  0.007333  0.007708  0.006659  0.007058  0.006053
#
# [2 rows x 60 columns]

# %%
data.isnull().sum()
# Out:
# 0.0200    0
# 0.0371    0
# 0.0428    0
# 0.0207    0
# 0.0954    0
#          ..
# 0.0180    0
# 0.0084    0
# 0.0090    0
# 0.0032    0
# R         0
# Length: 61, dtype: int64

# %%
X = data.iloc[:,:-1]
Y = data['R']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=65)

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train,y_train)*100, lr.score(x_test,y_test)*100
# Out:
# (84.84848484848484, 83.33333333333334)

# %% [markdown]
# # Prediction 1

# %%
input_data = [[0.0039,0.0063,0.0152,0.0336,0.031,0.0284,0.0396,0.0272,0.0323,0.0452,0.0492,0.0996,0.1424,0.1194,0.0628,0.0907,0.1177,0.1429,0.1223,0.1104,0.1847,0.3715,0.4382,0.5707,0.6654,0.7476,0.7654,0.8555,0.972,0.9221,0.7502,0.7209,0.7757,0.6055,0.5021,0.4499,0.3947,0.4281,0.4427,0.3749,0.1972,0.0511,0.0793,0.1269,0.1533,0.069,0.0402,0.0534,0.0228,0.0073,0.0062,0.0062,0.012,0.0052,0.0056,0.0093,0.0042,0.0003,0.0053,0.0036]]

# %%
dataframe = pd.DataFrame(input_data)

# %%
pre = lr.predict(dataframe)
# Out:
# C:\Users\hasna\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
if(pre == 'R'):
    print("There is a 'Rock' inside the ocean")

else:
    print("There is a 'Mine' inside the ocean")
    
print(pre)
# Out:
# There is a 'Rock' inside the ocean
# ['R']

# %% [markdown]
# # Prediction 2

# %%
mydata = [[0.0299,0.0688,0.0992,0.1021,0.0800,0.0629,0.0130,0.0813,0.1761,0.0998,0.0523,0.0904,0.2655,0.3099,0.3520,0.3892,0.3962,0.2449,0.2355,0.3045,0.3112,0.4698,0.5534,0.4532,0.4464,0.4670,0.4621,0.6988,0.7626,0.7025,0.7382,0.7446,0.7927,0.5227,0.3967,0.3042,0.1309,0.2408,0.1780,0.1598,0.5657,0.6443,0.4241,0.4567,0.5760,0.5293,0.3287,0.1283,0.0698,0.0334,0.0342,0.0459,0.0277,0.0172,0.0087,0.0046,0.0203,0.0130,0.0115,0.0015]]

# %%
Frame = pd.DataFrame(mydata)

# %%
myprediction = lr.predict(Frame)
# Out:
# C:\Users\hasna\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
if(myprediction == 'R'):
    print("There is a 'Rock' inside the ocean")

else:
    print("There is a 'Mine' inside the ocean")
    
print(myprediction)
# Out:
# There is a 'Mine' inside the ocean
# ['M']

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
scaling = ss.fit_transform(X)
